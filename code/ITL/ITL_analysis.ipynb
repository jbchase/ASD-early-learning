# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
from analysis import run_analysis

# %%
run_analysis(
    metadata_path="metadata/tsc2_det_female_metadata.csv",
    csv_folder="data/TSC2_Det_female",
    output_folder="output_csvs/tsc2_det_female"
)
