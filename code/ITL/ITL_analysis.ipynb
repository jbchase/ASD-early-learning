# %%
# %pip install matplotlib

# %%
from pathlib import Path

# %%
from analysis import run_analysis
from tail_analysis import run_tail_analysis

# %%
OUTPUT_FOLDER = "output_csvs/shank3b_det_female"

run_analysis(
    metadata_path="metadata/shank3b_det_female_metadata.csv",
    csv_folder="data/SHANK3B_Det_female",
    output_folder=OUTPUT_FOLDER
)

run_tail_analysis(
    input_csv=f"{OUTPUT_FOLDER}/trial_level_itl_all_rows.csv",
    output_folder=OUTPUT_FOLDER,
    percentile=95
)
# Out:
# Tail analysis figure saved to: output_csvs/shank3b_det_female
